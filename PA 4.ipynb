# %% [markdown]
# # PA 4

# %%
import pandas as pd

# %%
boards = pd.read_csv('board2.csv')
boards
# Out:
#    Name  Gender             Track  Hometown  Math  Electronics  GEAS  \
# 0    S1    Male   Instrumentation     Luzon    58           89    75
# 1    S2  Female     Communication  Mindanao    52           75    90
# 2    S3  Female   Instrumentation  Mindanao    83           74    77
# 3    S4    Male   Instrumentation   Visayas    65           58    91
# 4    S5    Male     Communication     Luzon    59           86    43
# 5    S6  Female  Microelectronics   Visayas    88           45    86
# 6    S7  Female   Instrumentation     Luzon    66           60    60
# 7    S8    Male   Instrumentation     Luzon    49           81    64
# 8    S9    Male   Instrumentation     Luzon    50           36    63
# 9   S10    Male  Microelectronics  Mindanao    80           84    61
# 10  S11  Female     Communication   Visayas    48           56    48
# 11  S12    Male     Communication   Visayas    89           67    84
# 12  S13  Female  Microelectronics     Luzon    88           35    83
# ...

# %%
boards.describe()
# Out:
#             Math  Electronics       GEAS  Communication    average
# count  30.000000     30.00000  30.000000      30.000000  30.000000
# mean   72.166667     61.60000  71.866667      61.966667  68.544444
# std    12.660237     17.29381  15.725519      15.376837   9.561851
# min    48.000000     35.00000  40.000000      41.000000  49.666667
# 25%    64.250000     47.00000  61.250000      49.000000  63.500000
# 50%    73.500000     60.00000  76.000000      60.000000  70.000000
# 75%    83.000000     76.50000  83.750000      72.750000  74.750000
# max    89.000000     91.00000  94.000000      88.000000  86.333333

# %% [markdown]
# # PROBLEM 1

# %% [markdown]
# ## Instru

# %%
Instru = boards.loc[(boards['Track'] == 'Instrumentation')&(boards['Hometown'] == 'Luzon')&(boards['Electronics']>70), ['Name','GEAS','Hometown','Electronics']]
Instru
# Out:
#    Name  GEAS Hometown  Electronics
# 0    S1    75    Luzon           89
# 7    S8    64    Luzon           81
# 29  S30    57    Luzon           81

# %% [markdown]
# ## Mandy

# %%
boards['average'] = boards[['Math', 'Electronics', 'GEAS']].mean(axis=1)
average
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[140], line 2
#       1 boards['average'] = boards[['Math', 'Electronics', 'GEAS']].mean(axis=1)
# ----> 2 average
#
# NameError: name 'average' is not defined

# %%
Mandy = boards.loc[(boards['Hometown'] == 'Mindanao')&(boards['Gender'] == 'Female')&(boards['average'] >= 55), ['Name','Track','Electronics', 'average']]
Mandy
# Out:
#    Name             Track  Electronics    average
# 1    S2     Communication           75  72.333333
# 2    S3   Instrumentation           74  78.000000
# 16  S17  Microelectronics           79  79.000000
# 19  S20     Communication           60  60.333333

# %% [markdown]
# # PROBLEM 2

# %%
plt.figure(figsize=(8,6))
boards.boxplot('average', 'Track')
plt.show()

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(20, 4))
plt.bar(boards['Hometown'], boards['Electronics'])
# Out:
# <BarContainer object of 30 artists>

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(20, 4))
plt.bar(boards['Hometown'], boards['Electronics'])
